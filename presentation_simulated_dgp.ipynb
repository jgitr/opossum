# %% [markdown]
# # Simulated Data Generating Process

# %% [markdown]
# ## Task: Simulate realistic data set with known treatment effects
#           Properties:
#                       - High dimensional and non-linear data
#                       - flexible
#                       - user friendly

# %% [markdown]
# ## Motivation
#
# Provide high quality data for research
#
# Useful for you to test your models

# %% [markdown]
# #### Model Equations
#
# see slide 5-1 Simulation Data

# %% [markdown]
# ## Treatment Assignment
#
# random with probability (0,1)
#
# non-random, depending on covariates

# %% [markdown]
# ## Details: Treatment effect
#
# continous heterogeneous
#
# negative
#
# no treatment effect
#
# constant

# %% [markdown]
# ## Composition of dependent variable
#
# non-linearity: g(...)=
#
# continuous: ...
#
# binary: ...

# %% [markdown]
# ## Implementation of module/package

# %%
from SimulateData import UserInterface

u = UserInterface(N = 1000,k = 10, seed = 7) 

u.generate_treatment(random_assignment = True, 
                    assignment_prob = 0.5, 
                    constant = True, 
                    heterogeneous = False,
                    negative = False, 
                    no_treatment = False, 
                    treatment_option_weights = [0, 0.7, 0.1, 0.2]) # default: None

y, X, assignment_vector, treatment_effect = u.output_data(binary=False)

# %%
# %matplotlib notebook

u.plot_covariates_correlation()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
    from plots import propensity_score_plt#, all_treatment_effect_plt, single_treatment_effect_plt, output_difference_plt 

    
    u = UserInterface(10000,10, seed=5)
    u.generate_treatment(random_assignment=False, treatment_option_weights = [1, 0, 0, 0])
    y, X, assignment, treatment = u.output_data()
    
    prop_score_conditioned = u.s.propensity_score

    
    u = UserInterface(10000,10, seed=5)
    u.generate_treatment(random_assignment=True, assignment_prob = 0.5,  treatment_option_weights = [1, 0, 0, 0])
    y, X, assignment, treatment = u.output_data()
    
    prop_score_random = u.s.propensity_score

# %% [markdown]
# ## Distributioin of probability assignment in conditioned and random case

# %%
    
    propensity_score_plt(prop_score_conditioned, prop_score_random)

# %% [markdown]
# ## Conditioned and random treatment assignment
#
#
# <img src="propensity_score_plot.png">
